# %%
import pandas as pd
# Out:
# /home/lorenzo-puppi/.local/lib/python3.12/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_parquet("civil_comments_explain.parquet.gzip")

data.pivot_table(
    index=['label'],
    columns=['offensive_related'],
    values="value",
    aggfunc=["count","mean"]
)
# Out:
#                   count            mean
# offensive_related False True      False     True
# label
# identity_attack      60    60  0.019764  0.851677
# insult             1563  1563  0.029101  0.844868
# obscene             138   138  0.034553  0.828234
# sexual_explicit      29    29  0.009606  0.840197
# threat               51    51  0.012108  0.848030
# toxicity           2105  2105  0.027449  0.847504

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7892 entries, 0 to 7891
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              7892 non-null   int64
#  1   split              7892 non-null   object
#  2   offensive_related  7892 non-null   bool
#  3   text               7892 non-null   object
#  4   label              7892 non-null   object
#  5   value              7892 non-null   float64
# dtypes: bool(1), float64(1), int64(1), object(3)
# memory usage: 316.1+ KB
