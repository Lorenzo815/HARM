# %% [markdown]
# # Due to an error (size limit to 50mb) when sending the full dataset we will attach a 10k rows version generated by the folowwing code
#
# ![image](./upload_dataset_error.png)

# %%
import pandas as pd

# %%
data = pd.read_parquet("./SBIC-Explain.parque.gzip")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123596 entries, 0 to 123595
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   base_model        123596 non-null  object
#  1   set               123596 non-null  object
#  2   post              123596 non-null  object
#  3   is_offensive      123596 non-null  float64
#  4   targetMinority    123596 non-null  object
#  5   targetCategory    123596 non-null  object
#  6   targetStereotype  123596 non-null  object
#  7   dataSource        123596 non-null  object
#  8   tier 1            123596 non-null  object
#  9   tier 2            123596 non-null  object
#  10  tier 3            123596 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 10.4+ MB

# %%
data.sample(n=10000).to_parquet("./SBIC-Explain_10k.parque.gzip")
